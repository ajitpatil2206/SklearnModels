# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("FuelConsumptionCo2.csv")

# %%
msk = np.random.rand(len(df)) < 0.8
print(msk)
# Out:
# [ True  True  True ...  True  True  True]

# %%
train = (df[msk])
test = (df[~msk])

# %%
print(len(train))
# Out:
# 873

# %%
print(len(test))
test
# Out:
# 194
#       MODELYEAR        MAKE                MODEL    VEHICLECLASS  ENGINESIZE  \
# 0          2014       ACURA                  ILX         COMPACT         2.0
# 1          2014       ACURA                  ILX         COMPACT         2.4
# 4          2014       ACURA              RDX AWD     SUV - SMALL         3.5
# 43         2014        AUDI  Q7 TDI CLEAN DIESEL  SUV - STANDARD         3.0
# 48         2014        AUDI            R8 SPYDER      TWO-SEATER         4.2
# ...         ...         ...                  ...             ...         ...
# 1039       2014  VOLKSWAGEN            JETTA GLI         COMPACT         2.0
# 1046       2014  VOLKSWAGEN               PASSAT        MID-SIZE         2.5
# 1047       2014  VOLKSWAGEN               PASSAT        MID-SIZE         3.6
# 1057       2014       VOLVO              S60 AWD         COMPACT         2.5
# 1060       2014       VOLVO              S80 AWD        MID-SIZE         3.0
#
# ...

# %%
# Out:
#   File "<ipython-input-66-b1ce15950f58>", line 1
#     df[[True True True]]
#              ^
# SyntaxError: invalid syntax
